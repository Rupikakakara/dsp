# %%
 import folium 
way1=[[16.78482431866904, 80.84620454142365],[16.679612585254755, 80.95194794641094],[16.741929817322983, 81.09443717325381],[16.737238052587557, 81.14016474037217],[16.751703955975877, 81.18099292529928],[16.78219473381896, 81.21973968631382],[16.811118164259813, 81.27055145234667],[16.809146252220025, 81.32479644581419],[16.828938827674865, 81.55210917573451],[16.784720091916668, 81.62832567589784],[16.76205399789618, 81.6727853009931],[16.762606861606855, 81.67220790326459],[16.747814678828757, 81.73630573938598],[16.68689417294341, 81.73559897368457],[16.620060455039546, 81.75317719292453],[16.60478027128558, 81.8085183228666]]
way2=[[16.78482431866904, 80.84620454142365],[16.679612585254755, 80.95194794641094],[16.741929817322983, 81.09443717325381],[16.737238052587557, 81.14016474037217],[16.751703955975877, 81.18099292529928],[16.78219473381896, 81.21973968631382],[16.811118164259813, 81.27055145234667],[16.809146252220025, 81.32479644581419],[16.828938827674865, 81.55210917573451],[16.784720091916668, 81.62832567589784],[16.76205399789618, 81.6727853009931],[16.762606861606855, 81.67220790326459],[16.747814678828757, 81.73630573938598],[16.747991577643788, 81.74759299455815],[16.624208897206355, 81.74005765082808],[16.60478027128558, 81.8085183228666]]
from branca.element import Figure
fig=Figure(width=550,height=350) 
f1=folium.FeatureGroup("Vehicle 1")
f2=folium.FeatureGroup("Vehicle 2") 
map=folium.Map(location=[16.780001,80.849998]) 
line_1=folium.vector_layers.PolyLine(way1,popup='Path of Vehicle_1',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1) 
line_2=folium.vector_layers.PolyLine(way2,popup='Path of Vehicle_2',tooltip='Vehicle_2',color='red',weight=10).add_to(f2) 
f1.add_to(map) 
f2.add_to(map) 
folium.Marker(location=[16.78482431866904, 80.84620454142365],popup='Startingpoint',tooltip='Nuzvidu',icon=folium.Icon(color='blue',prefix='fa',icon='university')).add_to(map) 
folium.Marker(location=[16.737238052587557, 81.14016474037217],tooltip='Eluru',icon=folium.Icon(color='purple',prefix='glyphicon',icon='bell')).add_to(map) 
folium.Marker(location=[16.751703955975877, 81.18099292529928],tooltip='Tanuku',icon=folium.Icon(color='blue',prefix='fa',icon='anchor')).add_to(map) 
folium.Marker(location=[16.60478027128558, 81.8085183228666],popup='Destination',tooltip='Achanta',icon=folium.Icon(color='blue',prefix='fa',icon='home')).add_to(map) 
folium.LayerControl().add_to(map) 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
